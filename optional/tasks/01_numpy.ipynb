# %%
import numpy as np

# %% [markdown]
# 1. Создать вектор (одномерный массив) размера 10, заполненный нулями

# %% [markdown]
# 2. Создать вектор размера 10, заполненный двойками

# %% [markdown]
# 3. Создать вектор со значениями от 5 до 100

# %% [markdown]
# 4. Создать вектор со значениями от 5 до 100, возвести в квадрат все элементы и посчитать сумму

# %% [markdown]
# 5. Развернуть вектор

# %% [markdown]
# 6. Создать матрицу 4x3 со значениями от 0 до 11 и развенуть по нулевой размерности

# %% [markdown]
# 7. Создать матрицу 4х3 случайных чисел из нормального распределения. Найти индекты элементов, которые больше нуля

# %% [markdown]
# 8. Создать матрицу 4х3 случайных чисел из нормального распределения. Сделать нормировку элеметнов (каждая колонка матрицы - это характеристика)
# $$ \frac{x-min(x)}{max(x) - min(x)} $$

# %% [markdown]
# 9. Создать 8x8 матрицу и заполнить её в шахматном порядке

# %% [markdown]
# 10. Сделать сортировку вектора

# %% [markdown]
# 11. Заменить максимальный элемент на минимальный

# %% [markdown]
# 12. Дан массив точек 10х2. Найти все попарные расстояния между точками

# %% [markdown]
# 13. Найти норму Фробениуса матрицы 4х4
# $$ norma = trace(A^T A) $$

# %% [markdown]
# 14. Объединить два массива размером 3х3 по 3-й оси
